# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import math

matplotlib.style.use('ggplot')

# %%
mpl.rcParams.keys()
# Out:
# [u'agg.path.chunksize',
#  u'animation.avconv_args',
#  u'animation.avconv_path',
#  u'animation.bitrate',
#  u'animation.codec',
#  u'animation.convert_args',
#  u'animation.convert_path',
#  u'animation.ffmpeg_args',
#  u'animation.ffmpeg_path',
#  u'animation.frame_format',
#  u'animation.html',
#  u'animation.mencoder_args',
#  u'animation.mencoder_path',
#  u'animation.writer',
#  u'axes.axisbelow',
#  u'axes.edgecolor',
#  u'axes.facecolor',
#  u'axes.formatter.limits',
#  u'axes.formatter.use_locale',
#  u'axes.formatter.use_mathtext',
#  u'axes.formatter.useoffset',
#  u'axes.grid',
#  u'axes.grid.axis',
#  u'axes.grid.which',
#  u'axes.hold',
#  u'axes.labelcolor',
#  u'axes.labelpad',
#  u'axes.labelsize',
#  u'axes.labelweight',
#  u'axes.linewidth',
#  u'axes.prop_cycle',
#  u'axes.spines.bottom',
#  u'axes.spines.left',
#  u'axes.spines.right',
#  u'axes.spines.top',
#  u'axes.titlesize',
#  u'axes.titleweight',
#  u'axes.unicode_minus',
#  u'axes.xmargin',
# ...

# %%
def bar_plot(dataframe, save_path):
    
    font_size = 14
    mpl.rcParams['xtick.labelsize'] = font_size
    mpl.rcParams['ytick.labelsize'] = font_size
    
    ax = dataframe.plot.bar(width=0.8, figsize=(15, 5), rot=0)
    
    # offset legend to the right
    lgd = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=font_size)

    # add value/text above each bar
    for p in ax.patches:
        ax.annotate("%.2f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=font_size)
        
    # scale y axis, don't start with 0
    low = dataframe.values.min()
    high = dataframe.values.max()
    plt.ylim(low-0.5*(high-low), 1)
    
    
    plt.savefig(save_path, bbox_extra_artists=(lgd,), bbox_inches='tight')
    return plt

# %%
# EU Speech Dataset Plot
cnn_a = {
    "accuracy": 0.904725609756,
    "precision": 0.91,
    "recall": 0.90,
    "f1": 0.90,
}

cnn_b = {
    "accuracy": 0.743902439024,
    "precision": 0.77,
    "recall": 0.74,
    "f1": 0.74,
}

cnn_c = {
    "accuracy": 0.679640718563,
    "precision": 0.73,
    "recall": 0.68,
    "f1": 0.678,
}

crnn = {
    "accuracy":  0.983231707317,
    "precision": 0.98,
    "recall": 0.98,
    "f1": 0.98,
}

data = pd.DataFrame([cnn_a, cnn_b, cnn_c, crnn], index=["CNN_A", "CNN_B", "CNN_C", "CRNN"])
bar_plot(data, "../thesis/plots/results_eu_plot.pdf")
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>

# %%
# YouTube news dataset plots
cnn = {
    "accuracy":  0.90,
    "precision": 0.91,
    "recall": 0.91,
    "f1": 0.91,
}

crnn = {
    "accuracy":  0.91092662413,
    "precision": 0.91,
    "recall": 0.91,
    "f1": 0.91,
}

inception = {
    "accuracy":  0.947759570766,
    "precision": 0.95,
    "recall": 0.95,
    "f1": 0.95,
}

inception_crnn = {
    "accuracy":  0.957112819026,
    "precision": 0.96,
    "recall": 0.96,
    "f1": 0.96,
}

data = pd.DataFrame([cnn, crnn, inception, inception_crnn], index=["CNN", "CRNN", "Inception-v3 CNN", "Inception-v3 CRNN"])
bar_plot(data, "../thesis/plots/results_news_plot.pdf")
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc'>
